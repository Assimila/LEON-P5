# %% [markdown]
# <div style='text-align:center;'>
# <figure><img src='https://raw.githubusercontent.com/wekeo/wekeo4data/main/img/LogoWekeo_Copernicus_RGB_0.png' alt='Logo EU Copernicus WEkEO' align='right' width='20%'>
# </figure>
# </div>
#
# <h1><center><code>How To Download WEkEO Data</code></center></h1>

# %% [markdown]
# Follow the next few steps to download data from WEkEO via the __HDA API__.
# Please check the following article to get further details:
# - [How to use the HDA API in Python?
# ](https://help.wekeo.eu/en/articles/6751608-how-to-use-the-hda-api-in-python)
# - [How to download WEkEO data?](https://help.wekeo.eu/en/articles/6416936-how-to-download-wekeo-data)
# - [Official documentation of HDA API](https://hda.readthedocs.io/en/latest/usage.html)

# %% [markdown]
# ## Step 1. Install the latest version of `hda`

# %% [markdown]
# You can run the next cell to install the latest version of `hda`:

# %%
# !pip install hda -U
# Out:
# Requirement already satisfied: hda in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (2.38)
# Collecting hda
#   Downloading hda-2.39-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.5.0 in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (from hda) (2.32.5)
# Requirement already satisfied: tqdm in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (from hda) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (from requests>=2.5.0->hda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (from requests>=2.5.0->hda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (from requests>=2.5.0->hda) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/georg/python/miniconda3/envs/copernicus/lib/python3.11/site-packages (from requests>=2.5.0->hda) (2025.11.12)
# Downloading hda-2.39-py3-none-any.whl (22 kB)
# Installing collected packages: hda
#   Attempting uninstall: hda
#     Found existing installation: hda 2.38
#     Uninstalling hda-2.38:
#       Successfully uninstalled hda-2.38
# Successfully installed hda-2.39

# %% [markdown]
# ## Step 2. Import `hda` module

# %% [markdown]
# The HDA Client provides a fully compliant Python3 Client that can be used to search and download products using the Harmonized Data Access WEkEO API. First let's import the `hda` functions:

# %%
from hda import Client, Configuration

# %% [markdown]
# ## Step 3. Configure credentials and load `hda` Client

# %% [markdown]
# Pass your credentials directly in the script:

# %%
# Configure your credentials without a .hdarc file
conf = Configuration(user = "xx", password = "xx")  # add your Wekeo username and password here
hda_client = Client(config = conf)

# %% [markdown]
# ## Step 4. Create the request and download data

# %% [markdown]
# ### Get the dataset metadata

# %% [markdown]
# Here we are going to download the following Copernicus Land dataset: __EO:EEA:DAT:CLMS_HRVPP_VPP__.
#
# To create our request we can ask to the API what parameters are needed.
# To do so we use the `metadata()` function:

# %%
# Request metadata of a dataset
hda_client.metadata(dataset_id="EO:EEA:DAT:CLMS_HRVPP_VPP")
# Out:
# {'type': 'object',
#  'title': 'Queryable',
#  'properties': {'dataset_id': {'title': 'dataset_id',
#    'type': 'string',
#    'oneOf': [{'const': 'EO:EEA:DAT:CLMS_HRVPP_VPP',
#      'title': 'EO:EEA:DAT:CLMS_HRVPP_VPP',
#      'group': None}]},
#   'itemsPerPage': {'title': 'Items PerPage',
#    'type': 'string',
#    'pattern': '^[0-9]*$'},
#   'startIndex': {'title': 'Start Index',
#    'type': 'string',
#    'pattern': '^[0-9]*$'},
#   'uid': {'title': 'Uid', 'type': 'string', 'pattern': '[\\w-]+'},
#   'productType': {'title': 'Product Type',
#    'type': 'string',
#    'oneOf': [{'const': 'MINV', 'title': 'MINV', 'group': None},
#     {'const': 'MAXD', 'title': 'MAXD', 'group': None},
#     {'const': 'LENGTH', 'title': 'LENGTH', 'group': None},
#     {'const': 'SOSD', 'title': 'SOSD', 'group': None},
#     {'const': 'QFLAG', 'title': 'QFLAG', 'group': None},
#     {'const': 'EOSV', 'title': 'EOSV', 'group': None},
#     {'const': 'TPROD', 'title': 'TPROD', 'group': None},
#     {'const': 'MAXV', 'title': 'MAXV', 'group': None},
#     {'const': 'AMPL', 'title': 'AMPL', 'group': None},
#     {'const': 'SOSV', 'title': 'SOSV', 'group': None},
#     {'const': 'LSLOPE', 'title': 'LSLOPE', 'group': None},
#     {'const': 'EOSD', 'title': 'EOSD', 'group': None},
#     {'const': 'RSLOPE', 'title': 'RSLOPE', 'group': None},
#     {'const': 'SPROD', 'title': 'SPROD', 'group': None}]},
#   'platformSerialIdentifier': {'title': 'Platform SerialIdentifier',
#    'type': 'string',
#    'oneOf': [{'const': 'S2A, S2B', 'title': 'S2A, S2B', 'group': None}]},
#   'tileId': {'title': 'Tile Id', 'type': 'string', 'pattern': '[\\w-]+'},
#   'productVersion': {'title': 'Product Version',
#    'type': 'string',
#    'pattern': '[\\w-]+'},
#   'productGroupId': {'title': 'Product GroupId',
#    'type': 'string',
#    'oneOf': [{'const': 's1', 'title': 's1', 'group': None},
#     {'const': 's2', 'title': 's2', 'group': None}]},
#   'resolution': {'title': 'Resolution',
#    'type': 'string',
#    'oneOf': [{'const': '10', 'title': '10', 'group': None}]},
#   'processingDate': {'title': 'Processing Date',
#    'type': 'string',
#    'format': 'date-time',
#    'minimum': '',
#    'maximum': '',
#    'default': ''},
#   'bbox': {'title': 'BBox',
#    'type': 'array',
#    'minItems': 4,
#    'maxItems': 4,
#    'items': [{'type': 'number', 'maximum': 180, 'minimum': -180},
#     {'type': 'number', 'maximum': 90, 'minimum': -90},
#     {'type': 'number', 'maximum': 180, 'minimum': -180},
#     {'type': 'number', 'maximum': 90, 'minimum': -90}]},
#   'startdate': {'title': 'Start Date',
#    'type': 'string',
#    'format': 'date-time',
#    'minimum': '',
#    'maximum': '',
#    'default': ''},
#   'enddate': {'title': 'End Date',
#    'type': 'string',
#    'format': 'date-time',
#    'minimum': '',
#    'maximum': '',
#    'default': ''}},
#  'required': ['dataset_id']}

# %% [markdown]
# ## Create the request

# %% [markdown]
# Based on this information we can create the request below.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     📌 <b>Note</b>: to learn how to get your query from the Data Viewer, please check <a href="https://help.wekeo.eu/en/articles/6416936-how-to-download-wekeo-data#h_85849dcd7a">this article</a>.
# </div>

# %% [markdown]
# ## Datasets

# %%
# Dynamic parameters
year = "2023"
resolution = "10m"
folder = "Crop_Type"
dataset = 'main_crop_type' 
country = 'nld'  # Change to: 'dnk', 'nld', 'uk'

# Bounding boxes dictionary
BBOXES = {
    'dnk': (8.076389, 54.559029, 15.193056, 57.751526),      # Denmark
    'nld': (3.360782, 50.723492, 7.227095, 53.554585),       # Netherlands
    'uk': (-4.723103, 50.201444, 1.764393, 52.998411),       # UK
}

# One-liner to get bbox
min_lon, min_lat, max_lon, max_lat = BBOXES[country.lower()]

print(f"✓ {country.upper()}: [{min_lon}, {min_lat}] to [{max_lon}, {max_lat}]")
# Out:
# ✓ NLD: [3.360782, 50.723492] to [7.227095, 53.554585]

# %% [markdown]
# ## Land Cover

# %% [markdown]
# ### CORINE land cover

# %%
query ={
  "dataset_id": "EO:EEA:DAT:CORINE",
  "format": "GeoTiff100mt",
  "productType": "Corine Land Cover 2018", # Corine Land Cover 2018, Corine Land Cover 2012, Corine Land Cover 2006, Corine Land Cover 2000, Corine Land Cover 1990
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### CLCplus Backbone

# %%
query = {
  "dataset_id": "EO:EEA:DAT:CLC-PLUS",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Raster Layer",
  "resolution": "10m",
  "year": year, # 2018, 2021, 2023
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ## Agriculture

# %% [markdown]
# ### Main Crop Emergence

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Main Crop Emergence",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Main Crop Type

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Crop Types",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Main Crop Harvest

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Main Crop Harvest",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Secondary Crop Emergence

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Secondary Crops Emergence",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Secondary Crop Type

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Secondary Crops Type",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Cropping Seasons Yearly

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Cropping Seasons Yearly",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Fallow Land Presence

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Fallow Land Presence",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Base Soil Before

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Bare Soil Before",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Bare Soil After

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:CRL",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Bare Soil After",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ##  Other

# %% [markdown]
# ### Small Woody Features

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:SLF",
  "productType": "Small Woody Features",
  "resolution": "5m",
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Riparian

# %%
query = {
  "dataset_id": "EO:EEA:DAT:RIPARIANZONES",
  "productType": "RZ 2018", # RZ 2012, RZ 2018
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Grassland

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:GRA",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Grassland",
  "resolution": resolution,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Tree Cover Density

# %%
query = {
  "dataset_id": "EO:EEA:DAT:HRL:TCF",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "productType": "Tree Cover Density",
  "resolution": "10m",     # 10m,20m,100m,
  "year": year,
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Natura 2000

# %%
query = {
  "dataset_id": "EO:EEA:DAT:N2K",
  "format": "geoPackage",
  "productType": "N2K 2018",  # N2K 2006, N2K 2012, N2K 2018
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# ### Burned Area

# %%
query = {
  "dataset_id": "EO:CLMS:DAT:CLMS_GLOBAL_BA_300M_V3_MONTHLY_NETCDF",
  "productType": "BA300",
  "productionStatus": "ARCHIVED",
  "acquisitionType": "NOMINAL",
  "platform": "SENTINEL-3",
  "processingCenter": "VITO",
  "productGroupId": "NTC",
  "resolution": "300",
  "bbox": [min_lon, min_lat, max_lon, max_lat],
  "startdate": "2019-01-01T00:00:00.000Z",
  "enddate": "2025-11-13T23:59:59.999Z",
  "itemsPerPage": 200,
  "startIndex": 0
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     📌 <b>Note</b>: the geographical coordinates in the <code>bbox</code> are ordered as: <code>[longitude_min, latitude_min, longitude_max, latitude_max]</code>
# </div>

# %% [markdown]
# ## Search data

# %% [markdown]
# The `search()` function launches the search of the data you requested with the specific parameters. It may take some time, as the server processes it.

# %%
matches = hda_client.search(query)
print(matches)
# Out:
# SearchResults[items=15,volume=99.3MB]

# %% [markdown]
# ## Download file(s)

# %% [markdown]
# On WEkEO's JupyterHub you are limited to 20GB of stockage space, so be careful of the total size of files your request generated.

# %% [markdown]
# ### Download files in the current working directory

# %% [markdown]
# You can run `matches.download()` to download all the files of your request.
# Please [read the documentation](https://hda.readthedocs.io/en/latest/usage.html#advanced-client-usage) for advanced usage such as:
# - downloading first result: `matches[0].download()`
# - downloading last result: `matches[-1].download()`
# - downloading first 10 results: `matches[:10].download()`
# - downloading even results: `matches[::2].download()`
# - etc.
#
# For the purpose of this example, we are going to fetch the last result:

# %%
OUTPUT_PATH = f'../../data/LEON_P5_BII/EO_data_raw/{folder}/{dataset}_{country}_{year}'
matches.download(OUTPUT_PATH)
print(f"Data downloaded to {OUTPUT_PATH}")
# Out:
# Data downloaded to ../../data/LEON_P5_BII/EO_data_raw/Crop_Type/main_crop_type_nld_2023

# %% [markdown]
# The `download()` function launches the download of the file(s) your request generated. They will be downloaded in the same folder as this notebook unless you specify an existing directory as `OUTPUT_PATH`.

# %% [markdown]
# ## Additional Information
# ---
#
# #### Compatible Data Science Toolkits

# %%
import pkg_resources; pkg_resources.get_distribution("hda").version
# Out:
# /tmp/ipykernel_3789/2528126426.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources; pkg_resources.get_distribution("hda").version
# '2.35'

# %% [markdown]
# #### Last Modified and Tested

# %%
from datetime import date; print(date.today())
# Out:
# 2025-11-06

# %% [markdown]
# <img src='https://github.com/wekeo/ai4EM_MOOC/raw/04147f290cfdcce341f819eab7ad037b95f25600/img/ai4eo_logos.jpg' alt='Logo EU Copernicus WEkEO' align='center' width='100%'></img>
